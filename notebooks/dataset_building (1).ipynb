# %%
# !pip install python-docx pandas
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.1.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import os
import pandas as pd
from docx import Document

# %%
def read_docx(file_path):
    doc = Document(file_path)
    text = []

    for para in doc.paragraphs:
        text.append(para.text)

    return "\n".join(text)

# %%
data = []

# %%
import os

print(os.listdir())
# Out:
# ['.config', 'drive', 'sample_data']

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Forex', 'Cryptocurrency .lnk', 'Personal ', 'Kayrand Designs Free Class Videos.lnk', 'VA Starter park', "Isaac's Consolidated", 'PMP', 'Google AI Studio', 'Linkedin ', 'AAI Classroom', 'Online Tutoring', 'Colab Notebooks', 'Copy of GCI World_202604', 'AI_Academic_Integrity_Project']

# %%
human_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/human_docs"

# %%
chatgpt_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/chatgpt_docs"

claude_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/claude_docs"

gemini_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/gemini_docs"

# %%
import os

print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['Forex', 'Cryptocurrency .lnk', 'Personal ', 'Kayrand Designs Free Class Videos.lnk', 'VA Starter park', "Isaac's Consolidated", 'PMP', 'Google AI Studio', 'Linkedin ', 'AAI Classroom', 'Online Tutoring', 'Colab Notebooks', 'Copy of GCI World_202604', 'AI_Academic_Integrity_Project']

# %%
print(os.listdir('/content/drive/MyDrive/AI_Academic_Integrity_Project'))
# Out:
# ['chatgpt_docs', 'claude_docs', 'gemini_docs', 'human_docs', 'academic_integrity_dataset.csv', 'cleaned_dataset.csv', 'models', 'model_comparison.png']

# %%
print(os.listdir('/content/drive/MyDrive/AI_Academic_Integrity_Project/human_docs'))
# Out:
# ['The Death Of Nigerian Literature.docx', 'Leave Me.docx', 'The Exceptional Mind.docx', 'Miseducation of Nigerian Poets.docx', 'STYLISTIC VARIATION.docx', 'Building Sex.docx', 'Meaning of Research.docx', 'RESEARCH PAPER WRITING TIPS.docx', 'INSTRUCTIONAL TECHNOLOGY IN PHYSICAL EDUCATION.docx', '730 Assignment .docx', 'Basic Economic Problems of Society and Resource Allocation.docx', 'THE IMPACT OF BOKO.docx', 'Meaning of Curriculum.docx', 'Spirit Wife.docx', 'The Advantages and Disadvantages of Remote Work.docx', 'AI empowered educators and education in Nigeria.docx', 'Pesticides and Fertilizers.docx']

# %%
human_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/human_docs"

# %%
import os

print(os.listdir(human_folder))
# Out:
# ['The Death Of Nigerian Literature.docx', 'Leave Me.docx', 'The Exceptional Mind.docx', 'Miseducation of Nigerian Poets.docx', 'STYLISTIC VARIATION.docx', 'Building Sex.docx', 'Meaning of Research.docx', 'RESEARCH PAPER WRITING TIPS.docx', 'INSTRUCTIONAL TECHNOLOGY IN PHYSICAL EDUCATION.docx', '730 Assignment .docx', 'Basic Economic Problems of Society and Resource Allocation.docx', 'THE IMPACT OF BOKO.docx', 'Meaning of Curriculum.docx', 'Spirit Wife.docx', 'The Advantages and Disadvantages of Remote Work.docx', 'AI empowered educators and education in Nigeria.docx', 'Pesticides and Fertilizers.docx']

# %%
from docx import Document

files = os.listdir(human_folder)

print(files[0])
# Out:
# The Death Of Nigerian Literature.docx

# %%
first_file = os.path.join(human_folder, files[0])

doc = Document(first_file)

print(doc.paragraphs[0].text)
# Out:
# The Death Of Nigerian Literature

# %%
human_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/human_docs"

chatgpt_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/chatgpt_docs"

claude_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/claude_docs"

gemini_folder = "/content/drive/MyDrive/AI_Academic_Integrity_Project/gemini_docs"

# %%
for file in os.listdir(human_folder):

    if file.endswith(".docx"):

        path = os.path.join(human_folder, file)

        text = read_docx(path)

        data.append({
            "text": text,
            "label": 0,
            "ai_model": "human"
        })

# %%
for file in os.listdir(chatgpt_folder):

    if file.endswith(".docx"):

        path = os.path.join(chatgpt_folder, file)

        text = read_docx(path)

        data.append({
            "text": text,
            "label": 1,
            "ai_model": "ChatGPT"
        })

# %%
for file in os.listdir(claude_folder):

    if file.endswith(".docx"):

        path = os.path.join(claude_folder, file)

        text = read_docx(path)

        data.append({
            "text": text,
            "label": 1,
            "ai_model": "Claude"
        })

# %%
for file in os.listdir(gemini_folder):

    if file.endswith(".docx"):

        path = os.path.join(gemini_folder, file)

        text = read_docx(path)

        data.append({
            "text": text,
            "label": 1,
            "ai_model": "Gemini"
        })

# %%
df = pd.DataFrame(data)

# %%
print(df.head())

print("Total samples:", len(df))
# Out:
#                                                 text  label ai_model
# 0  The Death Of Nigerian Literature\nby\nOris Aig...      0    human
# 1  Chinonso Nzeh paints a touching portrait of hi...      0    human
# 2  The essay explores Cyprian Ekwensi’s vocation ...      0    human
# 3  Chukwudera argues that Nigerian poets made sig...      0    human
# 4  STYLISTIC VARIATION \nStylistic variation can ...      0    human
# Total samples: 51

# %%
df.to_csv("/content/drive/MyDrive/AI_Academic_Integrity_Project/academic_integrity_dataset.csv", index=False)

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)

# %%
import nltk
import re

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words('english'))

lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text(text):

    # lowercase
    text = text.lower()

    # remove punctuation and numbers
    text = re.sub(r'[^a-zA-Z\s]', '', text)

    # tokenize
    tokens = word_tokenize(text)

    # remove stopwords + lemmatize
    cleaned_tokens = []

    for word in tokens:

        if word not in stop_words:

            lemma = lemmatizer.lemmatize(word)

            cleaned_tokens.append(lemma)

    return " ".join(cleaned_tokens)

# %%
text = text.lower()

# %%
re.sub(r'[^a-zA-Z\s]', '', text)
# Out:
# 'the agrochemical dilemma a critical analysis of pesticides and fertilizers\nthe modern agricultural revolution characterized by the transition from subsistence farming to highyield industrial production has been underpinned by the intensive use of agrochemicals among these synthetic fertilizers and pesticides represent the dual pillars of global food security while these chemical interventions have allowed for the exponential growth of the global food supply they have simultaneously introduced significant ecological perturbations this essay examines the essential benefits of pesticides and fertilizers in contemporary agriculture alongside the profound environmental consequences associated with their prolonged and unregulated use\n\nthe imperative of agrochemicals benefits to global agriculture\nthe primary justification for the use of pesticides and fertilizers is the necessity to meet the caloric demands of a surging global population without these inputs it is estimated that global crop yields would plummet by approximately  to \n optimization of soil nutrient profiles\nfertilizersprimarily composed of nitrogen n phosphorus p and potassium kserve to replenish soil nutrients that are naturally depleted during successive harvest cycles by providing a readily available source of essential elements fertilizers enable crops to grow faster larger and with higher nutritional density this intensification allows for greater output on smaller land areas theoretically reducing the need for horizontal expansion into forested regions\n crop protection and loss mitigation\npesticides encompassing herbicides insecticides and fungicides act as a vital line of defense against biotic stressors in the absence of pest control invasive species insects and fungal pathogens can decimate entire monocultures by controlling these threats pesticides ensure price stability in global food markets and prevent localized famines furthermore certain pesticides play a role in public health by controlling vectors of diseases such as malaria and west nile virus\n\nthe ecological cost environmental consequences\ndespite their utility the overapplication of agrochemicals has led to systemic environmental degradation affecting lithospheric hydrospheric and atmospheric integrity\n eutrophication and water contamination\nperhaps the most documented consequence of fertilizer use is the runoff of excess nutrients into aquatic ecosystems when nitrogen and phosphorus enter water bodies they trigger eutrophicationthe rapid proliferation of algae\nhypoxia as these algae die and decompose the process consumes vast amounts of dissolved oxygen leading to dead zones where aquatic life cannot survive\nnitrate leaching excessive nitrates from fertilizers can seep into groundwater posing significant health risks to human populations such as methemoglobinemia blue baby syndrome\n bioaccumulation and nontarget toxicity\npesticides are designed to be toxic and their lack of specificity often results in the unintended killing of nontarget organisms\nthe pollinator crisis the use of neonicotinoids has been strongly linked to the decline of honeybee populations which are essential for the pollination of onethird of the human diet\nbiomagnification persistent organic pollutants pops found in some pesticides do not break down easily they accumulate in the fatty tissues of organisms bioaccumulation and increase in concentration as they move up the food chain biomagnification leading to reproductive failure or death in apex predators such as raptors and large mammals\n soil degradation and greenhouse gas emissions\nironically the longterm use of synthetic fertilizers can lead to soil tiredness high concentrations of chemical salts can kill beneficial soil microbes disrupt the ph balance and lead to soil acidification furthermore the production and application of nitrogenous fertilizers are a major source of nitrous oxide no a greenhouse gas that is approximately  times more potent than  ...

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
df["clean_text"] = df["text"].apply(preprocess_text)

# %%
print(df[["text", "clean_text"]].head())
# Out:
#                                                 text  \
# 0  The Death Of Nigerian Literature\nby\nOris Aig...
# 1  Chinonso Nzeh paints a touching portrait of hi...
# 2  The essay explores Cyprian Ekwensi’s vocation ...
# 3  Chukwudera argues that Nigerian poets made sig...
# 4  STYLISTIC VARIATION \nStylistic variation can ...
#
#                                           clean_text
# 0  death nigerian literature oris aigbokhaevbolo ...
# 1  chinonso nzeh paint touching portrait struggle...
# 2  essay explores cyprian ekwensis vocation custo...
# 3  chukwudera argues nigerian poet made significa...
# 4  stylistic variation stylistic variation define...

# %%
df.to_csv(
    "/content/drive/MyDrive/AI_Academic_Integrity_Project/cleaned_dataset.csv",
    index=False
)

# %%
# Phase 3 - TF-IDF
# Import TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Create features (X) and Target (Y)
X = df["clean_text"]

y = df["label"]

# %%
# Create TF-IDF Object
vectorizer = TfidfVectorizer(max_features=5000)

# %%
# Fit and Transform text
X_tfidf = vectorizer.fit_transform(X)

# %%
# Check Shape
print(X_tfidf.shape)
# Out:
# (51, 5000)

# %%
# Split Training and Test Data
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf,
    y,
    test_size=0.2,
    random_state=42
)

# %%
# Check Shapes
print(X_train.shape)
print(X_test.shape)
# Out:
# (40, 5000)
# (11, 5000)

# %%
# Model Training
# Logistic Regression
# Import Model
from sklearn.linear_model import LogisticRegression

# %%
# Create Model
model = LogisticRegression()

# %%
# Train Model
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Model Predictions
y_pred = model.predict(X_test)

# %%
# Evaluate Model
from sklearn.metrics import accuracy_score, classification_report

# %%
# Check Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7272727272727273

# %%
# Performance Report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.73      1.00      0.84         8
#
#     accuracy                           0.73        11
#    macro avg       0.36      0.50      0.42        11
# weighted avg       0.53      0.73      0.61        11
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Confusion Matrix; correct predictions, wrong predictions.
# Import tools
from sklearn.metrics import confusion_matrix

# %%
# Create Matrix
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[0 3]
#  [0 8]]

# %%
# Matrix Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.heatmap(cm, annot=True, fmt='d')

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.title("Confusion Matrix")

plt.show()

# %%
# Random Forest Classifier
# Step 1 - Import Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
# Step 2 - Create Model
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# %%
# Train Model
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Make Predictions
rf_pred = rf_model.predict(X_test)

# %%
# Evaluate Model
from sklearn.metrics import accuracy_score, classification_report

rf_accuracy = accuracy_score(y_test, rf_pred)

print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.8181818181818182

# %%
# Performance report
print(classification_report(y_test, rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.33      0.50         3
#            1       0.80      1.00      0.89         8
#
#     accuracy                           0.82        11
#    macro avg       0.90      0.67      0.69        11
# weighted avg       0.85      0.82      0.78        11

# %%
# Confusion Matrix
rf_cm = confusion_matrix(y_test, rf_pred)

print(rf_cm)
# Out:
# [[1 2]
#  [0 8]]

# %%
# Visualize Random Forest Matrix
sns.heatmap(rf_cm, annot=True, fmt='d')

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.title("Random Forest Confusion Matrix")

plt.show()

# %%
# Neural Network
# Step 1 - Import TensorFlow
import tensorflow as tf

# %%
# Step 2 - Import Keras Components
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
# Step - 3 Check Data Shape
print(X_train.shape)
# Out:
# (40, 5000)

# %%
# Step 4 - Build Neural Network
nn_model = Sequential([
    Dense(64, activation='relu', input_shape=(5000,)),
    Dropout(0.3),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')

])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Step 5 - Compile Model
nn_model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Step 6 - Train Model
history = nn_model.fit(
    X_train,
    y_train,
    epochs=20,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.3500 - loss: 0.6958 - val_accuracy: 0.5455 - val_loss: 0.6903
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 614ms/step - accuracy: 0.8250 - loss: 0.6820 - val_accuracy: 0.7273 - val_loss: 0.6810
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step - accuracy: 0.9250 - loss: 0.6681 - val_accuracy: 0.7273 - val_loss: 0.6710
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step - accuracy: 0.9250 - loss: 0.6588 - val_accuracy: 0.7273 - val_loss: 0.6600
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.9500 - loss: 0.6364 - val_accuracy: 0.7273 - val_loss: 0.6479
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.9500 - loss: 0.6220 - val_accuracy: 0.7273 - val_loss: 0.6345
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.9500 - loss: 0.6014 - val_accuracy: 0.7273 - val_loss: 0.6184
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 371ms/step - accuracy: 0.9250 - loss: 0.5820 - val_accuracy: 0.7273 - val_loss: 0.6011
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step - accuracy: 0.9250 - loss: 0.5575 - val_accuracy: 0.8182 - val_loss: 0.5832
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - accuracy: 0.9500 - loss: 0.5260 - val_accuracy: 0.8182 - val_loss: 0.5651
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 1.0000 - loss: 0.5009 - val_accuracy: 0.8182 - val_loss: 0.5464
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step - accuracy: 0.9750 - loss: 0.4870 - val_accuracy: 0.8182 - val_loss: 0.5284
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 434ms/step - accuracy: 1.0000 - loss: 0.4457 - val_accuracy: 0.8182 - val_loss: 0.5101
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9750 - loss: 0.4107 - val_accuracy: 0.8182 - val_loss: 0.4918
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.3967 - val_accuracy: 0.8182 - val_loss: 0.4727
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.3590 - val_accuracy: 0.8182 - val_loss: 0.4539
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 1.0000 - loss: 0.3275 - val_accuracy: 0.8182 - val_loss: 0.4354
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.3081 - val_accuracy: 0.8182 - val_loss: 0.4174
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 1.0000 - loss: 0.2797 - val_accuracy: 0.8182 - val_loss: 0.3998
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 1.0000 - loss: 0.2421 - val_accuracy: 0.8182 - val_loss: 0.3835

# %%
# Step 7 - Evaluate Model
loss, accuracy = nn_model.evaluate(X_test, y_test)

print("Neural Network Accuracy:", accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8182 - loss: 0.3835
# Neural Network Accuracy: 0.8181818127632141

# %%
# Step 8 - Plot Loss Curves
# Import visualization libraries
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')

plt.plot(history.history['val_loss'], label='Validation Loss')

plt.xlabel('Epochs')

plt.ylabel('Loss')

plt.title('Training vs Validation Loss')

plt.legend()

plt.show()

# %% [markdown]
# Experimenting With Architecture

# %%
# Experiment 1 - More Neurons
nn_model2 = Sequential([

    Dense(128, activation='relu', input_shape=(5000,)),

    Dropout(0.4),

    Dense(64, activation='relu'),

    Dense(1, activation='sigmoid')
])

# %%
# Compile
nn_model2.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Train
history2 = nn_model2.fit(
    X_train,
    y_train,
    epochs=20,
    validation_data=(X_test, y_test),
    verbose=1
)
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 645ms/step - accuracy: 0.3500 - loss: 0.6971 - val_accuracy: 0.7273 - val_loss: 0.6820
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - accuracy: 0.9500 - loss: 0.6755 - val_accuracy: 0.7273 - val_loss: 0.6689
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.8000 - loss: 0.6610 - val_accuracy: 0.7273 - val_loss: 0.6548
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.8750 - loss: 0.6425 - val_accuracy: 0.7273 - val_loss: 0.6386
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.8500 - loss: 0.6193 - val_accuracy: 0.7273 - val_loss: 0.6209
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.9000 - loss: 0.5990 - val_accuracy: 0.7273 - val_loss: 0.6018
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step - accuracy: 0.9000 - loss: 0.5691 - val_accuracy: 0.7273 - val_loss: 0.5807
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.9250 - loss: 0.5410 - val_accuracy: 0.7273 - val_loss: 0.5579
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9500 - loss: 0.5023 - val_accuracy: 0.7273 - val_loss: 0.5346
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.9250 - loss: 0.4755 - val_accuracy: 0.7273 - val_loss: 0.5108
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.9250 - loss: 0.4481 - val_accuracy: 0.8182 - val_loss: 0.4871
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 1.0000 - loss: 0.3932 - val_accuracy: 0.8182 - val_loss: 0.4619
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.3586 - val_accuracy: 0.8182 - val_loss: 0.4365
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 1.0000 - loss: 0.3157 - val_accuracy: 0.8182 - val_loss: 0.4114
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 1.0000 - loss: 0.2775 - val_accuracy: 0.8182 - val_loss: 0.3882
# Epoch 16/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 1.0000 - loss: 0.2357 - val_accuracy: 0.8182 - val_loss: 0.3675
# Epoch 17/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 1.0000 - loss: 0.1965 - val_accuracy: 0.8182 - val_loss: 0.3484
# Epoch 18/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 1.0000 - loss: 0.1699 - val_accuracy: 0.8182 - val_loss: 0.3299
# Epoch 19/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 1.0000 - loss: 0.1459 - val_accuracy: 0.8182 - val_loss: 0.3118
# Epoch 20/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 1.0000 - loss: 0.1181 - val_accuracy: 0.8182 - val_loss: 0.2944

# %%
# Evaluate
loss2, accuracy2 = nn_model2.evaluate(X_test, y_test)

print("Experiment Model Accuracy:", accuracy2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8182 - loss: 0.2944
# Experiment Model Accuracy: 0.8181818127632141

# %% [markdown]
# Saving the best trained model

# %%
# Saving NN_Model
nn_model.save(
    "/content/drive/MyDrive/AI_Academic_Integrity_Project/models/ai_detection_model.h5"
)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Save TF-IDF Vectorizer
import pickle

with open(
    "/content/drive/MyDrive/AI_Academic_Integrity_Project/models/tfidf_vectorizer.pkl",
    "wb"
) as f:

    pickle.dump(vectorizer, f)

# %%
# Accuracy comparison Chart
models = [
    "Logistic Regression",
    "Random Forest",
    "Neural Network"
]

accuracies = [
    0.73,
    0.81,
    0.818
]

import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(models, accuracies)

plt.ylabel("Accuracy")

plt.title("Model Comparison")

plt.ylim(0,1)

plt.show()

# %%
plt.savefig(
    "/content/drive/MyDrive/AI_Academic_Integrity_Project/model_comparison.png"
)
